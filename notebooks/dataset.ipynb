# %%
import os
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
depth_path = os.path.expanduser('~/Projects/curly_slam/data/soulcity/depth_image/000000_left_depth.tiff')
depth = cv2.imread(depth_path, cv2.IMREAD_UNCHANGED)

# %%
frame_id = 100
file_index = '0'*(6-len(str(frame_id)))+str(frame_id)
f'depth_image/{file_index}_left_depth.tiff'
# Out:
# 'depth_image/000100_left_depth.tiff'

# %%
import numpy as np
file_path = os.path.expanduser('~/Projects/curly_slam/data/soulcity/depth_left/000001_left_depth.npy')
depth = np.load(file_path)

# %%
color_path = os.path.expanduser('~/Projects/curly_slam/data/soulcity/image_left/000054_left.png')
color = cv2.imread(color_path)
out = np.concatenate([color,color], axis=1)
img = out[:,:,::-1]
plt.imshow(img)

# %%
depth
# Out:
# array([[0.3125    , 0.31323242, 0.31396484, ..., 0.89697266, 0.8955078 ,
#         0.89404297],
#        [0.31274414, 0.31347656, 0.31420898, ..., 0.89697266, 0.8955078 ,
#         0.89404297],
#        [0.31298828, 0.3137207 , 0.31445312, ..., 0.89697266, 0.8955078 ,
#         0.89404297],
#        ...,
#        [0.5024414 , 0.50439453, 0.50634766, ..., 0.9082031 , 0.9067383 ,
#         0.90527344],
#        [0.5029297 , 0.5048828 , 0.50683594, ..., 0.9082031 , 0.9067383 ,
#         0.90527344],
#        [0.50390625, 0.5058594 , 0.5078125 , ..., 0.9082031 , 0.9067383 ,
#         0.90527344]], dtype=float32)
